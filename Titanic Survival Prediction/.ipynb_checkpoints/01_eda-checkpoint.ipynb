# %%
pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupyter in /Users/vish/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: pandas in /Users/vish/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: numpy in /Users/vish/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: matplotlib in /Users/vish/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 4)) (3.9.4)
# Requirement already satisfied: seaborn in /Users/vish/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: scikit-learn in /Users/vish/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 6)) (1.6.1)
# Requirement already satisfied: notebook in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter->-r requirements.txt (line 1)) (7.5.5)
# Requirement already satisfied: jupyter-console in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter->-r requirements.txt (line 1)) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter->-r requirements.txt (line 1)) (7.17.1)
# Requirement already satisfied: ipykernel in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter->-r requirements.txt (line 1)) (6.31.0)
# Requirement already satisfied: ipywidgets in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter->-r requirements.txt (line 1)) (8.1.8)
# Requirement already satisfied: jupyterlab in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter->-r requirements.txt (line 1)) (4.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from pandas->-r requirements.txt (line 2)) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from pandas->-r requirements.txt (line 2)) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 4)) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 4)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 4)) (26.2)
# Requirement already satisfied: pillow>=8 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 4)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 4)) (3.3.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 4)) (6.5.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from scikit-learn->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 4)) (3.23.1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: appnope>=0.1.2 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (8.18.1)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: decorator in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: stack-data in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: typing-extensions in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: exceptiongroup in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: pexpect>4.3 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: wcwidth in /Users/vish/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.8.6)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=8.0.0->ipykernel->jupyter->-r requirements.txt (line 1)) (8.7.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (58.0.4)
# Requirement already satisfied: tomli>=1.2.2 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: anyio in /Users/vish/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (4.12.1)
# Requirement already satisfied: certifi in /Users/vish/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/vish/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: idna in /Users/vish/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.13)
# Requirement already satisfied: h11>=0.16 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (4.25.1)
# Requirement already satisfied: requests>=2.31 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.32.5)
# Requirement already satisfied: argon2-cffi-bindings in /Users/vish/Library/Python/3.9/lib/python/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jinja2>=3.0.3->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.27.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.1.1)
# Requirement already satisfied: fqdn in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: uri-template in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/vish/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/vish/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: webencodings in /Users/vish/Library/Python/3.9/lib/python/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.6.3)
# Requirement already satisfied: lark>=1.2.2 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pycparser in /Users/vish/Library/Python/3.9/lib/python/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2.23)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 1)) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/vish/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/vish/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)
plt.rcParams["figure.dpi"] = 100

# %matplotlib inline

# %%
df = pd.read_csv("data/titanic.csv")
print (f"Dataset Shape: {df.shape[0]} rows, {df.shape[1]} columns")
df.head(10)
# Out:
# Dataset Shape: 891 rows, 12 columns
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
# Data types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Statistical summary of numerical columns
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Statistical summary of categorical columns
df.describe(include="object")
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
# Count and percentage of missing values
missing=pd.DataFrame({
    "Missing Count": df.isnull().sum(),
    "Missing %": (df.isnull().sum() / len(df) * 100).round(2)
})
missing = missing[missing["Missing Count"] > 0].sort_values("Missing %", ascending = False)
print("Columns with missing values:")
missing
# Out:
# Columns with missing values:
#           Missing Count  Missing %
# Cabin               687      77.10
# Age                 177      19.87
# Embarked              2       0.22

# %%
# Visualize missing values
